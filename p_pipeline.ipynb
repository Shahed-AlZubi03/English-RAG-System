# %% [markdown]
# **Extract The Plain Text**

# %%
import json
from pathlib import Path
import re
from nltk.tokenize import sent_tokenize
from docx import Document

def extract_clean_text_from_docx(docx_path: str):
    """
    Extract text from a Word document (.docx) and merge headings into their paragraphs.
    Output: list of dicts { "paragraph_id": int, "sentence": str }
    """
    doc = Document(docx_path)

    paragraphs_text = []  # will hold merged heading+paragraphs or bullets
    buffer = []
    current_heading = None  # store heading text until we see the paragraph

    def flush_buffer():
        """helper to flush bullet buffer into one block"""
        nonlocal buffer, paragraphs_text
        if buffer:
            paragraphs_text.append(" ".join(buffer))
            buffer = []

    for para in doc.paragraphs:
        text = para.text.strip()
        style_name = para.style.name if para.style else ""

        if not text:
            flush_buffer()
            continue

        # normalize whitespace
        text = re.sub(r'\s+', ' ', text)

        # if it's a heading
        if style_name.startswith("Heading"):
            flush_buffer()
            current_heading = text
            continue  # skip adding heading separately, wait for next para

        # if it's a bullet
        if text.startswith("●") or text.startswith("-"):
            # part of a bullet list, accumulate
            if current_heading:
                # prepend heading to the first bullet block
                text = f"{current_heading}: {text}"
                current_heading = None
            buffer.append(text)
        else:
            # normal paragraph, flush previous bullets
            flush_buffer()
            if current_heading:
                text = f"{current_heading}: {text}"
                current_heading = None
            paragraphs_text.append(text)

    # flush leftover bullets at the end
    flush_buffer()

    # now paragraphs_text holds merged bullets and normal paragraphs with heading text included
    sentences_with_para = []
    paragraph_id = 1
    for para_text in paragraphs_text:
        sentences = sent_tokenize(para_text)
        for sent in sentences:
            sentences_with_para.append({
                "paragraph_id": paragraph_id,
                "sentence": sent.strip()
            })
        paragraph_id += 1

    return sentences_with_para


def reconstruct_clean_text(sentences_with_para):
    """Reconstructs paragraphs from sentences with paragraph IDs."""
    paragraphs = []
    current_para_id = -1
    para_sentences = []

    for item in sentences_with_para:
        if item["paragraph_id"] != current_para_id:
            if para_sentences:
                paragraphs.append(" ".join(para_sentences))
            para_sentences = [item["sentence"]]
            current_para_id = item["paragraph_id"]
        else:
            para_sentences.append(item["sentence"])
    
    if para_sentences:
        paragraphs.append(" ".join(para_sentences))
    
    return "\n\n".join(paragraphs)


def save_text_to_file(text: str, output_path: str) -> None:
    """Saves text to a file."""
    Path(output_path).write_text(text, encoding="utf-8")
    print(f"Cleaned text saved to: {output_path}")


if __name__ == "__main__":
    docx_file = r"C:\Users\Shahe\my_server\RAG\rag_sys\political\Transparency and efficiency.docx"
    output_file = r"C:\Users\Shahe\my_server\RAG\rag_sys\political\plain_text.txt"

    sentences_data = extract_clean_text_from_docx(docx_file)
    cleaned_text = reconstruct_clean_text(sentences_data)
    save_text_to_file(cleaned_text, output_file)

    print("CLEANED TEXT (Preview):\n", cleaned_text[:1000])

    # Save sentences_data to JSON exactly as requested
    json_output_file = Path(r"C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_data.json")
    json_output_file.write_text(
        json.dumps(sentences_data, ensure_ascii=False, indent=2),
        encoding="utf-8"
    )

    print(f"sentences_data saved to JSON: {json_output_file}")
# Out:
# Cleaned text saved to: C:\Users\Shahe\my_server\RAG\rag_sys\political\plain_text.txt
# CLEANED TEXT (Preview):
#  Introduction: There is a delicate balance between transparency and decision-making effectiveness, as transparency can be a double-edged weapon. Although it strengthens democracy and allows citizens and stakeholders to participate in the decision-making process, it may sometimes be hampered by increased complexity and delays.
#
# On the one hand, opponents of transparency consider that they may lose effectiveness to decision-making processes, as they can cause delays in decision-making due to multiple public debates and intervention by external actors. On the other hand, proponents of transparency see it as enhancing legitimacy and accountability and ensuring that decisions are made in the public's interest.
#
# Thus, there seems to be a need for an ideal balance between transparency and decision-making effectiveness, as transparency must be made available to citizens and stakeholders without unduly complicating or delaying decision-making processes. The solution may be to develop effective m
# sentences_data saved to JSON: C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_data.json

# %% [markdown]
# **Embedding sentences from JSON**

# %%
import json
from pathlib import Path
from sentence_transformers import SentenceTransformer

# --- Input / output paths ---
json_file = r"C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_data.json"  # your input file
output_file = r"C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_with_embeddings.json"

# --- Load sentences (expects a list of dicts like {"paragraph_id": ..., "sentence": ...}) ---
sentences = json.loads(Path(json_file).read_text(encoding="utf-8"))

# --- Load embedding model ---
model = SentenceTransformer("multi-qa-mpnet-base-dot-v1")

# --- Compute embeddings while preserving paragraph_id ---
sentences_with_embeddings = []
for record in sentences:
    paragraph_id = record["paragraph_id"]
    sentence_text = record["sentence"]

    embedding = model.encode(
        sentence_text,
        normalize_embeddings=True  # optional but good for cosine similarity
    ).tolist()

    sentences_with_embeddings.append({
        "paragraph_id": paragraph_id,
        "sentence": sentence_text,
        "embedding": embedding
    })

# --- Save to JSON ---
Path(output_file).write_text(
    json.dumps(sentences_with_embeddings, ensure_ascii=False, indent=2),
    encoding="utf-8"
)

print(f"Saved sentences with embeddings to: {output_file}")
# Out:
# Saved sentences with embeddings to: C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_with_embeddings.json

# %% [markdown]
# **Clustering By Topic**

# %%
import json
import numpy as np
from pathlib import Path
from bertopic import BERTopic

# ----------------------------
# 1. Load your JSON file
# ----------------------------
sentences_data = json.loads(
    Path(r"C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_with_embeddings.json")
    .read_text(encoding="utf-8")
)

# extract texts and embeddings
texts = [item["sentence"] for item in sentences_data]
paragraph_ids = [item["paragraph_id"] for item in sentences_data]
embeddings = np.array([item["embedding"] for item in sentences_data])

print(f"Loaded {len(texts)} sentences with embeddings of shape {embeddings.shape}")

# ----------------------------
# 2. Create and fit BERTopic
# ----------------------------
# By default BERTopic uses its own embedding model. Because we already have embeddings,
# we pass `embedding_model=None` and supply embeddings ourselves.
topic_model = BERTopic(embedding_model=None, verbose=True)

# Fit the model using our own embeddings
topics, probs = topic_model.fit_transform(texts, embeddings)

# ----------------------------
# 3. Inspect topics
# ----------------------------
# Topic number for each sentence:
for text, topic_id, pid in zip(texts, topics, paragraph_ids):
    print(f"[Paragraph {pid}] Topic {topic_id}: {text}")

# Summary info about all topics:
print("\n=== Topic Info ===")
print(topic_model.get_topic_info())  # shows topic id, size, and name keywords

# Inspect one topic's keywords:
print("\n=== Top words in topic 0 ===")
print(topic_model.get_topic(0))  # list of top words with scores

# ----------------------------
# 4. (Optional) Save topics per sentence to JSON
# ----------------------------
output = []
for item, topic_id in zip(sentences_data, topics):
    out_item = {
        "paragraph_id": item["paragraph_id"],
        "sentence": item["sentence"],
        "topic": int(topic_id)
    }
    output.append(out_item)

Path(r"C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_with_topics.json").write_text(
    json.dumps(output, ensure_ascii=False, indent=2),
    encoding="utf-8"
)
print("\nSaved topics to sentences_with_topics.json")
# Out:
# 2025-09-18 22:59:17,123 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# Loaded 108 sentences with embeddings of shape (108, 768)
# 2025-09-18 22:59:42,470 - BERTopic - Dimensionality - Completed ✓
# 2025-09-18 22:59:42,487 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-09-18 22:59:42,547 - BERTopic - Cluster - Completed ✓
# 2025-09-18 22:59:42,570 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-09-18 22:59:42,619 - BERTopic - Representation - Completed ✓
# [Paragraph 1] Topic 0: Introduction: There is a delicate balance between transparency and decision-making effectiveness, as transparency can be a double-edged weapon.
# [Paragraph 1] Topic 0: Although it strengthens democracy and allows citizens and stakeholders to participate in the decision-making process, it may sometimes be hampered by increased complexity and delays.
# [Paragraph 2] Topic 0: On the one hand, opponents of transparency consider that they may lose effectiveness to decision-making processes, as they can cause delays in decision-making due to multiple public debates and intervention by external actors.
# [Paragraph 2] Topic 0: On the other hand, proponents of transparency see it as enhancing legitimacy and accountability and ensuring that decisions are made in the public's interest.
# [Paragraph 3] Topic 0: Thus, there seems to be a need for an ideal balance between transparency and decision-making effectiveness, as transparency must be made available to citizens and stakeholders without unduly complicating or delaying decision-making processes.
# [Paragraph 3] Topic 0: The solution may be to develop effective mechanisms to manage potential complexities and ensure smooth decision-making processes, while maintaining a high level of transparency and public participation.
# [Paragraph 4] Topic -1: Transparency is an important principle of democracy and accountability, but it may have negative implications for political decision-making.
# [Paragraph 4] Topic 0: In the area of decision-making in particular, transparency may reduce the chances of reaching satisfactory agreements for all.
# [Paragraph 4] Topic 0: There are several reasons for this:
# [Paragraph 5] Topic 0: First, transparency may reduce the efficiency of policy outcomes.
# [Paragraph 5] Topic 0: When the public is aware of the details of the decision, decision makers may be pressured to maintain certain positions or claim additional benefits.
# [Paragraph 5] Topic 0: This can complicate decision-making, increase its duration, and reduce its flexibility.
# [Paragraph 5] Topic 0: This may lead to less quality, less comprehensive or less stable agreements.
# [Paragraph 6] Topic 0: Second, transparency may reduce decision makers' ability to reach agreement in the first place.
# [Paragraph 6] Topic 0: When policy options are disclosed, the number of acceptable options for decision makers may decrease.
# [Paragraph 6] Topic 0: This is because the public may reject, criticize, or oppose certain options.
# [Paragraph 6] Topic 0: Consequently, it may become difficult for decision makers to move away from their initial positions or prejudice certain interests.
# [Paragraph 6] Topic 0: This may reduce bargaining space and increase the risk of stalemate or failure.
# [Paragraph 7] Topic 0: Third, transparency may increase the use of public commitment strategies.
# [Paragraph 7] Topic 0: These are strategies in which decision makers publicly and openly state their negotiating positions, with a view to strengthening their position or undermining others' position.
# [Paragraph 7] Topic 0: This increases transaction costs resulting from changing, modifying, or reversing these positions.
# [Paragraph 7] Topic 0: This reduces decision makers' incentives for cooperation, consensus, or central solutions.
# [Paragraph 7] Topic 0: This increases the likelihood of conflict, division, or breakdown.
# [Paragraph 8] Topic 0: Based on these reasons, it can be said that transparency is not always useful.
# [Paragraph 8] Topic 0: Sometimes they can be an obstacle or a danger to achieving the desired goals.
# [Paragraph 8] Topic 0: There must therefore be a balance between transparency and confidentiality, and the appropriate level of transparency must be chosen for each case, depending on the circumstances (Hagemann, Franchino 2016, p.3).
# [Paragraph 9] Topic -1: Transparency: Academic definitions of transparency tend to focus on either its process or purpose, although with some overlap.
# [Paragraph 9] Topic 1: For the former, the emphasis is on the degree to which an organization makes explicit information concerning aspects such as its decision-making processes, performance, and procedures.
# [Paragraph 9] Topic -1: for example, define transparency as ‘the availability of information for navigating a large-scale social system.’
# [Paragraph 10] Topic -1: Although the definition of transparency has expanded over time and diversity of presentation, the definition of its concept remains the focus of many researchers and institutions.
# [Paragraph 10] Topic -1: On the one hand, Hood's definition of transparency, which places emphasis on providing information from top to bottom, but without containing the necessary practical elements, such as ensuring privacy, is important but insufficient.
# [Paragraph 11] Topic 1: On the other hand, the European Union's definition of transparency is more detailed, focusing on citizens' right to know how and by whom European institutions prepare decisions, and this includes multiple aspects such as sources of funding and documents for the preparation of laws.
# [Paragraph 11] Topic 1: However, the definition of the European Parliament is more specific, focusing on the role of transparency as a means of facilitating citizens' scrutiny of the activities of Parliament, especially with regard to its legislative work.
# [Paragraph 12] Topic 1: In addition, the European Court of Auditors' Office points to the importance of transparency as a means of disclosing information about management and activities and disseminating audit results, thereby promoting the concept of good governance and accountability.
# [Paragraph 13] Topic 1: In short, the definition of transparency varies according to context and purpose, with each definition seeking to clarify the right to access information and its importance in ensuring transparency and accountability.
# [Paragraph 14] Topic 0: The European Union's decision-making studies indicate that there are several factors affecting the efficiency of these processes, including the distribution of preferences and voting rules.
# [Paragraph 14] Topic 0: The majority vote is known to tend to take decisions faster than the unanimous rules (Golub, 2007).
# [Paragraph 15] Topic -1: The European Union has evolved over time, increasing the number of member States to 27, and the nature of legislative decision-making has changed with two chambers, leading researchers to explore the impact of these developments.
# [Paragraph 15] Topic 0: Some studies have found that the European Parliament's involvement slows decision-making, even in cases where it has only an advisory role.
# [Paragraph 16] Topic -1: As for the number of Member States represented in the Council of Ministers, the evidence shows mixed.
# [Paragraph 16] Topic 0: While some find that the enlargement of the European Union accelerates the decision-making process, others see it as slowing down, and there are those who find little impact.
# [Paragraph 17] Topic 0: Thus, it appears that multiple factors play a role in the efficiency of decision-making in the European Union, and understanding these factors can help improve decision-making processes and enhance administrative and political effectiveness within the European Union.
# [Paragraph 18] Topic 0: In addition to known factors affecting the European Union's decision-making processes, some studies focus on other manifestations of political complexity that are not linked to the number of member States in the Council of Ministers or the institutional role of the European Parliament (Dru ̈ ner et al.
# [Paragraph 18] Topic -1: 2018).
# [Paragraph 19] Topic 0: For example, a study showed that long acquisitions depend not only on choosing one of the options available, but also on finding a solution at the initial stage.
# [Paragraph 19] Topic 0: A study also noted that different forms of political disagreement had a strong impact on the duration of negotiations (Brandsma 2015).
# [Paragraph 20] Topic 0: In the same vein, a study has shown that stakeholders' participation in the legislative drafting phase could prolong decision-making processes, arguing that consultations increase the cost of transactions for subsequent negotiation, affecting the duration of legislative processes (Rasmussen and Toshkov 2013).
# [Paragraph 21] Topic 0: In addition, although transparency has not emerged as a direct determinant of decision-making, some studies suggest that decision-making processes can be influenced by the extent to which surveillance and social narratives of these processes exist within the Cabinet (Stasavage 2004).
# [Paragraph 21] Topic -1: For example, some studies have suggested that processes that are surrounded by surveillance may take longer, while one has shown that the publication of votes and legislative records usually does not slow down decision-making (Hagemann and Franchino 2016).
# [Paragraph 22] Topic 0: It is important to note that these studies highlight the complexities of EU decision-making, which includes not only direct political factors, but also social and institutional aspects that play a role in shaping and impacting these processes.
# [Paragraph 23] Topic 0: There seems to be a strong belief among decision makers that transparency negatively affects decision-making efficiency.
# [Paragraph 23] Topic 0: In this sense, they resist external pressure that seeks to increase levels of transparency, considering that institutions need "space for reflection" without external interference or pressure.
# [Paragraph 23] Topic 0: But we must wonder whether this belief is based on concrete and scientific evidence?
# [Paragraph 23] Topic 0: Does transparency actually affect decision-making, as decision makers believe?
# [Paragraph 24] Topic 0: On the other hand, the use of transparency can sometimes be strategic by decision makers, as it can be used as a means to engage in negotiations and accelerate them rather than slow them down.
# [Paragraph 24] Topic 0: Thus, there seems to be a discrepancy in how transparency affects the decision-making process, and it cannot be asserted that it always affects negatively.
# [Paragraph 25] Topic 0: But in fact, to better understand the relationship between transparency and decision-making efficiency, more thorough research is needed.
# [Paragraph 25] Topic 0: In fact, the relationship between them is very complex and demonstrates or denies how accurately and scientifically transparency affects.
# [Paragraph 25] Topic 0: Through these studies, we can determine whether or not the beliefs among decision makers are correct and develop effective strategies to improve decision-making in the current context.
# [Paragraph 26] Topic 1: E-transparency: The increase in the provision of information about the EU's online operations, which track recent technological developments, has been reflected in the use of electronic transparency innovations.
# [Paragraph 26] Topic 1: This shift towards online transparency shows the evolution of Internet access, with the proportion of citizens with Internet access increasing markedly.
# [Paragraph 26] Topic 1: This shift is known as terms such as "computer-brokered transparency" and "ICT transparency" (Bannister and Connolly, 2012).
# [Paragraph 27] Topic 1: Electronic transparency according to Railiene (2015) is an application of the principles of public transparency using ICT.
# [Paragraph 27] Topic -1: However, academic definitions of electronic transparency usually focus on specific aspects.
# [Paragraph 27] Topic -1: Therefore, it is important that the definition of electronic transparency is designed in a way that captures all these entirely different features.
# [Paragraph 28] Topic 1: Through the compilation of academic research, the extent to which information provided by electronic transparency tools meets users' needs, especially with regard to completeness, ease of use and accuracy.
# [Paragraph 28] Topic 1: Real-time and retroactive information can be distinguished, and a number of researchers, such as Heald (2006) and Heritier (2003), emphasize the importance of the public's access to information.
# [Paragraph 29] Topic 1: By accommodating the diverse features of academic literature, a comprehensive set of standards can be developed to define electronic transparency reasonably and appropriately.
# [Paragraph 29] Topic -1: Table 1 summarizes the main features of transparency identified in academic literature, which can be applied to the European Union's electronic transparency tools.
# [Paragraph 30] Topic 1: Notably, this shift towards electronic transparency points to radical changes in how information is made available and accessible, a key to enhancing transparency and strengthening trust between Governments and citizens (Field 2017).
# [Paragraph 31] Topic 1: Electronic transparency is defined as online access to accurate, comprehensive, and timely information about a particular EU political process.
# [Paragraph 32] Topic 1: E-transparency is a broader framework related to e-government and e-democracy issues.
# [Paragraph 32] Topic 1: E-government means the use of technology to provide government services and information, while e-democracy means the use of technology to enable citizens to participate in decision-making.
# [Paragraph 33] Topic 1: Electronic transparency is an important tool for the EU, providing an opportunity for the public to access information and understand the decision-making process.
# [Paragraph 33] Topic 0: It also serves as a channel for citizenship participation in this process, where individuals can express their views and observations directly and effectively.
# [Paragraph 34] Topic 1: In addition, electronic transparency enhances the level of transparency and accountability in government work, where citizens can monitor the authorities' performance and demand accountability for their decisions and actions.
# [Paragraph 35] Topic 1: Thus, the importance of electronic transparency as an essential tool in promoting democracy and confidence-building between the Government and citizens of the European Union is demonstrated.
# [Paragraph 36] Topic 1: In terms of the views as to the primary purpose of e-transparency, the distinction between unelected officials and elected representatives was clear, as was the marked difference between the views of those operating inside the institutions and those campaigning from outside.
# [Paragraph 36] Topic 1: Officials at both the EP and Commission took a view that the degree of transparency of the legislative process compares favorably to that in some member states.
# [Paragraph 36] Topic 1: This suggests that it is only by direct comparison with the situation in member states that enhanced EU e-transparency tools can lead to legitimacy gains.
# [Paragraph 36] Topic 1: Commission officials tended to assume a link between e-transparency and the EU’s legitimacy, although the linking mechanisms were not clear.
# [Paragraph 36] Topic 0: In Curtin and Meijer’s exploration of the linkages between these ideas, they suggest that greater transparency leads to social acceptance of the policy-making structures and that this – in turn – leads to greater input legitimacy (Curtin and Meijer, 2006; Scharpf, 2009).
# [Paragraph 36] Topic 1: For e-transparency, however, this social acceptance will only occur if there is a public appetite for utilizing the transparency tools in the first place.
# [Paragraph 36] Topic 1: Expressed more simply, using e-transparency tools to increase the public visibility of EU processes will not lead to legitimacy gains unless there is sufficient public interest in the processes in the first place.
# [Paragraph 36] Topic 1: Indeed, by focusing chiefly on the provision of legislative transparency – often technical and requiring some understanding of the EU’s institutional workings – the e-transparency mechanisms may actually deter engagement by the non-specialist, invalidating the intended legitimacy gains (Field 2017).
# [Paragraph 37] Topic 1: In terms of the transparency portal hosted on the Europa website, Commission officials acknowledge it does not add any new transparency systems, rather it acts as a ‘one stop shop’, allowing users to view pre-existing e-transparency tools from a single access point.
# [Paragraph 37] Topic 1: As such, evaluating the impact of this portal illustrates the difficulty of trying to capture the effectiveness of e-transparency systems through a single conceptual lens.
# [Paragraph 38] Topic 1: It was striking how often MEPs favorably compared the EP’s e-transparency processes to those at the Commission.
# [Paragraph 38] Topic 0: This would seem to indicate that, despite an increase in both formal and informal ties operating at the institutional level (Egeberg et al., 2014), some inter-institutional enmity remains among the individual actors involved.
# [Paragraph 38] Topic 1: Overall, MEPs overwhelmingly saw e-transparency’s principal function as enhancing and rebuilding trust in the EU in general and in the EP in particular.
# [Paragraph 39] Topic -1: Legislative transparency is a controversial topic in any political system, where researchers' appreciation of its benefits and disadvantages varies in making decision makers' records publicly available.
# [Paragraph 39] Topic 1: In the context of the Council of the European Union, the records of Governments' decisions have been publicly available for some time, but these general documents have been insufficient in providing details on the content of the proposed policies and the individual positions of Council members on these proposals.
# [Paragraph 39] Topic 0: Although there has been this evolution in the trend towards greater transparency in the Council, this does not necessarily mean that there is a direct correlation between transparency and the efficiency of the Council's decision-making process.
# [Paragraph 40] Topic 0: In fact, some research suggests that transparency may reduce the efficiency of decision-making, as it can complicate and slow processes as a result of increased public debate and debate.
# [Paragraph 40] Topic 0: However, transparency can also promote democracy and accountability, as the public can demand more details of decision-making processes and leaders' positions.
# [Paragraph 41] Topic 1: Through a detailed study of the impact of legislative transparency, we can understand how to improve this process to achieve the ideal balance between transparency and the efficiency of decisions in the EU.
# [Paragraph 41] Topic 1: It is important that we identify best practices and policies that can help enhance the effectiveness of transparency without negatively affecting the functioning of the Council's decision-making and operational processes and, ultimately, support democracy and accountability in the EU.
# [Paragraph 42] Topic 1: Indeed, the topic of legislative transparency in the European Union is a contentious one that provokes many debates and analyses in political and academic circles.
# [Paragraph 42] Topic 1: Academic research has shown mixed results on the benefits and disadvantages of making the political records of EU decision makers public.
# [Paragraph 42] Topic 1: Although the records of Governments' decisions had been publicly available for some time, there had been a lack of complete information on the policy content of the proposal adopted, as well as on the positions of individual legislators on those proposals.
# [Paragraph 43] Topic 1: However, the EU is currently seeing a general trend towards increased transparency in its operations, including the inclusion of more information in the public records of EU enterprises.
# [Paragraph 43] Topic -1: However, it must be emphasized that making legislative records public does not come as a direct trade-off with the efficiency of policy processes.
# [Paragraph 43] Topic 0: While some studies have concluded that transparency may reduce the efficiency of decision-making, others see it as contributing to its improvement.
# [Paragraph 44] Topic 1: A model applied by some researchers shows how public access to EU legislative records can contribute to overcoming incomplete information problems, which can reduce the risk of negotiation failure and increase the efficiency of decision-making.
# [Paragraph 44] Topic 1: Research also suggests that electronic transparency, based on the use of ICT, can contribute to enhancing transparency and improving EU decision-making processes.
# [Paragraph 45] Topic 1: Although there are challenges to the implementation of the European Union's electronic transparency tools, such as the lack of end-users of these tools and the need for an independent control framework, efforts in this direction are a positive step towards enhancing transparency and accountability in the European Union.
# [Paragraph 45] Topic -1: This reflects the growing interest in promoting the principles of democracy and transparency in this complex political context (Field 2017).
# [Paragraph 46] Topic -1: Al Bara'a Al Zu'bi
#
# === Topic Info ===
#    Topic  Count                         Name  \
# 0     -1     16  -1_of_the_transparency_that
# 1      0     52  0_the_and_decisionmaking_of
# 2      1     40              1_the_of_and_to
#
#                                       Representation  \
# 0  [of, the, transparency, that, definition, in, ...
# 1  [the, and, decisionmaking, of, that, in, to, t...
# 2  [the, of, and, to, transparency, in, informati...
#
#                                  Representative_Docs
# 0  [For example, some studies have suggested that...
# 1  [Although there has been this evolution in the...
# 2  [Thus, the importance of electronic transparen...
#
# === Top words in topic 0 ===
# [('the', np.float64(0.09795369974925024)), ('and', np.float64(0.08499627838177308)), ('decisionmaking', np.float64(0.0779209922146069)), ('of', np.float64(0.06857954240932808)), ('that', np.float64(0.06847571637785324)), ('in', np.float64(0.06655014135551521)), ('to', np.float64(0.06586211108637993)), ('transparency', np.float64(0.06201683074792003)), ('be', np.float64(0.05282242996753834)), ('or', np.float64(0.052372907740040844))]
#
# Saved topics to sentences_with_topics.json

# %% [markdown]
# **Merge By Topic**

# %%
import json
from pathlib import Path
from collections import defaultdict

# ----------------------------
# 1. Load sentences with topics
# ----------------------------
sentences_with_topics = json.loads(
    Path(r"C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_with_topics.json")
    .read_text(encoding="utf-8")
)

# ----------------------------
# 2. Group by topic
# ----------------------------
topics_dict = defaultdict(list)

for item in sentences_with_topics:
    topic_id = item["topic"]
    # Store sentence along with its paragraph_id
    sentence_info = {
        "paragraph_id": item["paragraph_id"],
        "sentence": item["sentence"]
    }
    topics_dict[topic_id].append(sentence_info)

# ----------------------------
# 3. Merge into single text per topic
# ----------------------------
merged_topics = []
for topic_id, sentence_infos in topics_dict.items():
    # Merge text for the chunk
    merged_text = " ".join([s["sentence"] for s in sentence_infos])
    merged_topics.append({
        "topic": int(topic_id),
        "text": merged_text,
        "sentences": sentence_infos  # keep metadata per sentence
    })

# ----------------------------
# 4. Save to JSON
# ----------------------------
output_path = r"C:\Users\Shahe\my_server\RAG\rag_sys\political\topics_merged.json"
Path(output_path).write_text(
    json.dumps(merged_topics, ensure_ascii=False, indent=2),
    encoding="utf-8"
)

print(f"Merged topics saved to {output_path}")
# Out:
# Merged topics saved to C:\Users\Shahe\my_server\RAG\rag_sys\political\topics_merged.json

# %% [markdown]
# **Embedding for Each Chunk**

# %%
import json
from pathlib import Path
import numpy as np
from sentence_transformers import SentenceTransformer

# ----------------------------
# 1. Load merged topics
# ----------------------------
merged_topics = json.loads(
    Path(r"C:\Users\Shahe\my_server\RAG\rag_sys\political\topics_merged.json")
    .read_text(encoding="utf-8")
)

# ----------------------------
# 2. Load embedding model
# ----------------------------
embedding_model = SentenceTransformer("multi-qa-mpnet-base-dot-v1")

# ----------------------------
# 3. Compute embeddings for each chunk text
# ----------------------------
chunks_with_embeddings = []
for topic_chunk in merged_topics:
    chunk_text = topic_chunk["text"]
    embedding = embedding_model.encode(chunk_text)  # single embedding for whole chunk

    chunks_with_embeddings.append({
        "topic": topic_chunk["topic"],
        "text": chunk_text,
        "embedding": embedding.tolist(),  # convert to list for JSON
        "sentences": topic_chunk["sentences"]
    })

# ----------------------------
# 4. Save to JSON
# ----------------------------
output_path = r"C:\Users\Shahe\my_server\RAG\rag_sys\political\new_chunks_with_embeddings.json"
Path(output_path).write_text(
    json.dumps(chunks_with_embeddings, ensure_ascii=False, indent=2),
    encoding="utf-8"
)

print(f"Chunk embeddings saved to {output_path}")
# Out:
# Chunk embeddings saved to C:\Users\Shahe\my_server\RAG\rag_sys\political\new_chunks_with_embeddings.json

# %% [markdown]
# **Paragraph Embedding**

# %%
import json
from sentence_transformers import SentenceTransformer
from collections import defaultdict

# Initialize model
embedding_model = SentenceTransformer("multi-qa-mpnet-base-dot-v1")

# Load sentences
with open(r"C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_with_embeddings.json", 'r', encoding='utf-8') as f:
    sentences_data = json.load(f)

# Group sentences by paragraph_id
paragraph_map = defaultdict(list)
for item in sentences_data:
    paragraph_map[item['paragraph_id']].append(item['sentence'])

# Precompute paragraph + sentence embeddings
paragraphs = []
for para_id, sentences in paragraph_map.items():
    # encode each sentence separately → list of embeddings
    sentence_embeddings = embedding_model.encode(sentences).tolist()

    # encode the full paragraph (optional)
    para_text = " ".join(sentences)
    para_emb = embedding_model.encode(para_text).tolist()

    paragraphs.append({
        "paragraph_id": para_id,
        "sentences": sentences,                   # ✅ sentences saved as list
       # "sentence_embeddings": sentence_embeddings,  # ✅ each sentence embedding
        "text": para_text,
        "paragraph_embedding": para_emb
    })

# Save to JSON for future fast loading
out_path = r"C:\Users\Shahe\my_server\RAG\rag_sys\political\paragraphs_with_embeddings.json"
with open(out_path, "w", encoding="utf-8") as f:
    json.dump(paragraphs, f, ensure_ascii=False, indent=2)

print(f"Paragraph + sentence embeddings precomputed and saved to {out_path}")
# Out:
# Paragraph + sentence embeddings precomputed and saved to C:\Users\Shahe\my_server\RAG\rag_sys\political\paragraphs_with_embeddings.json
