# %% [markdown]
# **Load Embeddings & Build Vector Indexes**

# %%
import json
import numpy as np
import faiss

# --- Load your stored embeddings ---
with open(r"C:\Users\Shahe\my_server\RAG\rag_sys\political\paragraphs_with_embeddings.json") as f:
    paragraphs = json.load(f)  # [{'id':..., 'text':..., 'embedding':[...]}]

with open(r"C:\Users\Shahe\my_server\RAG\rag_sys\political\sentences_with_embeddings.json") as f:
    sentences = json.load(f)

# Convert to numpy arrays
para_embeddings = np.array([p["paragraph_embedding"] for p in paragraphs]).astype("float32")
sent_embeddings = np.array([s["embedding"] for s in sentences]).astype("float32")

# --- Build FAISS indexes ---
dim = para_embeddings.shape[1]  # embedding dimension
para_index = faiss.IndexFlatIP(dim)  # cosine similarity (inner product)
sent_index = faiss.IndexFlatIP(dim)

# Normalize for cosine similarity
faiss.normalize_L2(para_embeddings)
faiss.normalize_L2(sent_embeddings)

para_index.add(para_embeddings)
sent_index.add(sent_embeddings)

# %% [markdown]
# **Stage 1: Retrieve Top-K Paragraphs**

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# load same embedding model for queries
query_model = SentenceTransformer("multi-qa-mpnet-base-dot-v1")

def retrieve_paragraphs(query, top_k=5, threshold=0.7):
    q_emb = query_model.encode([query], convert_to_numpy=True).astype("float32")
    faiss.normalize_L2(q_emb)

    scores, idxs = para_index.search(q_emb, top_k)
    results = []
    for score, idx in zip(scores[0], idxs[0]):
        if score >= threshold:
            results.append({
                "id": paragraphs[idx]["paragraph_id"],
                "sentences": paragraphs[idx]["sentences"],
                "text": paragraphs[idx]["text"],
                "score": float(score)
            })
    return results

# Example:
#top_paragraphs = retrieve_paragraphs("Explain the system architecture")

# %%
top_paragraphs = retrieve_paragraphs("How does transparency impact decision-making?")
top_paragraphs
# Out:
# [{'id': 24,
#   'sentences': ['On the other hand, the use of transparency can sometimes be strategic by decision makers, as it can be used as a means to engage in negotiations and accelerate them rather than slow them down.',
#    'Thus, there seems to be a discrepancy in how transparency affects the decision-making process, and it cannot be asserted that it always affects negatively.'],
#   'text': 'On the other hand, the use of transparency can sometimes be strategic by decision makers, as it can be used as a means to engage in negotiations and accelerate them rather than slow them down. Thus, there seems to be a discrepancy in how transparency affects the decision-making process, and it cannot be asserted that it always affects negatively.',
#   'score': 0.8230322599411011},
#  {'id': 23,
#   'sentences': ['There seems to be a strong belief among decision makers that transparency negatively affects decision-making efficiency.',
#    'In this sense, they resist external pressure that seeks to increase levels of transparency, considering that institutions need "space for reflection" without external interference or pressure.',
#    'But we must wonder whether this belief is based on concrete and scientific evidence?',
#    'Does transparency actually affect decision-making, as decision makers believe?'],
#   'text': 'There seems to be a strong belief among decision makers that transparency negatively affects decision-making efficiency. In this sense, they resist external pressure that seeks to increase levels of transparency, considering that institutions need "space for reflection" without external interference or pressure. But we must wonder whether this belief is based on concrete and scientific evidence? Does transparency actually affect decision-making, as decision makers believe?',
#   'score': 0.7860391139984131},
#  {'id': 40,
#   'sentences': ['In fact, some research suggests that transparency may reduce the efficiency of decision-making, as it can complicate and slow processes as a result of increased public debate and debate.',
#    "However, transparency can also promote democracy and accountability, as the public can demand more details of decision-making processes and leaders' positions."],
#   'text': "In fact, some research suggests that transparency may reduce the efficiency of decision-making, as it can complicate and slow processes as a result of increased public debate and debate. However, transparency can also promote democracy and accountability, as the public can demand more details of decision-making processes and leaders' positions.",
#   'score': 0.7688031196594238},
#  {'id': 25,
#   'sentences': ['But in fact, to better understand the relationship between transparency and decision-making efficiency, more thorough research is needed.',
#    'In fact, the relationship between them is very complex and demonstrates or denies how accurately and scientifically transparency affects.',
#    'Through these studies, we can determine whether or not the beliefs among decision makers are correct and develop effective strategies to improve decision-making in the current context.'],
#   'text': 'But in fact, to better understand the relationship between transparency and decision-making efficiency, more thorough research is needed. In fact, the relationship between them is very complex and demonstrates or denies how accurately and scientifically transparency affects. Through these studies, we can determine whether or not the beliefs among decision makers are correct and develop effective strategies to improve decision-making in the current context.',
#   'score': 0.7588362693786621},
#  {'id': 1,
#   'sentences': ['Introduction: There is a delicate balance between transparency and decision-making effectiveness, as transparency can be a double-edged weapon.',
#    'Although it strengthens democracy and allows citizens and stakeholders to participate in the decision-making process, it may sometimes be hampered by increased complexity and delays.'],
#   'text': 'Introduction: There is a delicate balance between transparency and decision-making effectiveness, as transparency can be a double-edged weapon. Although it strengthens democracy and allows citizens and stakeholders to participate in the decision-making process, it may sometimes be hampered by increased complexity and delays.',
#   'score': 0.7381700277328491}]

# %% [markdown]
# **Retrieve Top-K Chunks**

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import faiss
import json

# 1️⃣ Load same embedding model for queries
query_model = SentenceTransformer("multi-qa-mpnet-base-dot-v1")

# 2️⃣ Load your chunks + build index (once)
with open(r"C:\Users\Shahe\my_server\RAG\rag_sys\political\new_chunks_with_embeddings.json", "r", encoding="utf-8") as f:
    chunks = json.load(f)  # list of dicts: {"topic": int, "text": str, "embedding": [...]}

emb_matrix = np.array([c["embedding"] for c in chunks]).astype("float32")
faiss.normalize_L2(emb_matrix)

chunk_index = faiss.IndexFlatIP(emb_matrix.shape[1])  # inner product for cosine sim
chunk_index.add(emb_matrix)

# 3️⃣ Retrieval function
def retrieve_chunks(query, top_k=5, threshold=0.7):
    # embed & normalize query
    q_emb = query_model.encode([query], convert_to_numpy=True).astype("float32")
    faiss.normalize_L2(q_emb)

    scores, idxs = chunk_index.search(q_emb, top_k)

    results = []
    for score, idx in zip(scores[0], idxs[0]):
        if score >= threshold:
            results.append({
                "topic": chunks[idx]["topic"], 
                "sentences": [s["sentence"] for s in chunks[idx]["sentences"]],
                "text": chunks[idx]["text"],
                "score": float(score)
            })
    return results

# %%
top_chunks = retrieve_chunks("How does transparency impact decision-making?")
top_chunks
# Out:
# [{'topic': 0,
#   'sentences': ['Introduction: There is a delicate balance between transparency and decision-making effectiveness, as transparency can be a double-edged weapon.',
#    'Although it strengthens democracy and allows citizens and stakeholders to participate in the decision-making process, it may sometimes be hampered by increased complexity and delays.',
#    'On the one hand, opponents of transparency consider that they may lose effectiveness to decision-making processes, as they can cause delays in decision-making due to multiple public debates and intervention by external actors.',
#    "On the other hand, proponents of transparency see it as enhancing legitimacy and accountability and ensuring that decisions are made in the public's interest.",
#    'Thus, there seems to be a need for an ideal balance between transparency and decision-making effectiveness, as transparency must be made available to citizens and stakeholders without unduly complicating or delaying decision-making processes.',
#    'The solution may be to develop effective mechanisms to manage potential complexities and ensure smooth decision-making processes, while maintaining a high level of transparency and public participation.',
#    'In the area of decision-making in particular, transparency may reduce the chances of reaching satisfactory agreements for all.',
#    'There are several reasons for this:',
#    'First, transparency may reduce the efficiency of policy outcomes.',
#    'When the public is aware of the details of the decision, decision makers may be pressured to maintain certain positions or claim additional benefits.',
#    'This can complicate decision-making, increase its duration, and reduce its flexibility.',
#    'This may lead to less quality, less comprehensive or less stable agreements.',
#    "Second, transparency may reduce decision makers' ability to reach agreement in the first place.",
#    'When policy options are disclosed, the number of acceptable options for decision makers may decrease.',
#    'This is because the public may reject, criticize, or oppose certain options.',
#    'Consequently, it may become difficult for decision makers to move away from their initial positions or prejudice certain interests.',
#    'This may reduce bargaining space and increase the risk of stalemate or failure.',
#    'Third, transparency may increase the use of public commitment strategies.',
#    "These are strategies in which decision makers publicly and openly state their negotiating positions, with a view to strengthening their position or undermining others' position.",
#    'This increases transaction costs resulting from changing, modifying, or reversing these positions.',
#    "This reduces decision makers' incentives for cooperation, consensus, or central solutions.",
#    'This increases the likelihood of conflict, division, or breakdown.',
#    'Based on these reasons, it can be said that transparency is not always useful.',
#    'Sometimes they can be an obstacle or a danger to achieving the desired goals.',
#    'There must therefore be a balance between transparency and confidentiality, and the appropriate level of transparency must be chosen for each case, depending on the circumstances (Hagemann, Franchino 2016, p.3).',
#    "The European Union's decision-making studies indicate that there are several factors affecting the efficiency of these processes, including the distribution of preferences and voting rules.",
#    'The majority vote is known to tend to take decisions faster than the unanimous rules (Golub, 2007).',
#    "Some studies have found that the European Parliament's involvement slows decision-making, even in cases where it has only an advisory role.",
#    'While some find that the enlargement of the European Union accelerates the decision-making process, others see it as slowing down, and there are those who find little impact.',
#    'Thus, it appears that multiple factors play a role in the efficiency of decision-making in the European Union, and understanding these factors can help improve decision-making processes and enhance administrative and political effectiveness within the European Union.',
#    "In addition to known factors affecting the European Union's decision-making processes, some studies focus on other manifestations of political complexity that are not linked to the number of member States in the Council of Ministers or the institutional role of the European Parliament (Dru ̈ ner et al.",
#    'For example, a study showed that long acquisitions depend not only on choosing one of the options available, but also on finding a solution at the initial stage.',
#    'A study also noted that different forms of political disagreement had a strong impact on the duration of negotiations (Brandsma 2015).',
#    "In the same vein, a study has shown that stakeholders' participation in the legislative drafting phase could prolong decision-making processes, arguing that consultations increase the cost of transactions for subsequent negotiation, affecting the duration of legislative processes (Rasmussen and Toshkov 2013).",
#    'In addition, although transparency has not emerged as a direct determinant of decision-making, some studies suggest that decision-making processes can be influenced by the extent to which surveillance and social narratives of these processes exist within the Cabinet (Stasavage 2004).',
#    'It is important to note that these studies highlight the complexities of EU decision-making, which includes not only direct political factors, but also social and institutional aspects that play a role in shaping and impacting these processes.',
#    'There seems to be a strong belief among decision makers that transparency negatively affects decision-making efficiency.',
#    'In this sense, they resist external pressure that seeks to increase levels of transparency, considering that institutions need "space for reflection" without external interference or pressure.',
#    'But we must wonder whether this belief is based on concrete and scientific evidence?',
#    'Does transparency actually affect decision-making, as decision makers believe?',
#    'On the other hand, the use of transparency can sometimes be strategic by decision makers, as it can be used as a means to engage in negotiations and accelerate them rather than slow them down.',
#    'Thus, there seems to be a discrepancy in how transparency affects the decision-making process, and it cannot be asserted that it always affects negatively.',
#    'But in fact, to better understand the relationship between transparency and decision-making efficiency, more thorough research is needed.',
#    'In fact, the relationship between them is very complex and demonstrates or denies how accurately and scientifically transparency affects.',
#    'Through these studies, we can determine whether or not the beliefs among decision makers are correct and develop effective strategies to improve decision-making in the current context.',
#    'It also serves as a channel for citizenship participation in this process, where individuals can express their views and observations directly and effectively.',
#    'In Curtin and Meijer’s exploration of the linkages between these ideas, they suggest that greater transparency leads to social acceptance of the policy-making structures and that this – in turn – leads to greater input legitimacy (Curtin and Meijer, 2006; Scharpf, 2009).',
#    'This would seem to indicate that, despite an increase in both formal and informal ties operating at the institutional level (Egeberg et al., 2014), some inter-institutional enmity remains among the individual actors involved.',
#    "Although there has been this evolution in the trend towards greater transparency in the Council, this does not necessarily mean that there is a direct correlation between transparency and the efficiency of the Council's decision-making process.",
#    'In fact, some research suggests that transparency may reduce the efficiency of decision-making, as it can complicate and slow processes as a result of increased public debate and debate.',
#    "However, transparency can also promote democracy and accountability, as the public can demand more details of decision-making processes and leaders' positions.",
#    'While some studies have concluded that transparency may reduce the efficiency of decision-making, others see it as contributing to its improvement.'],
#   'text': 'Introduction: There is a delicate balance between transparency and `decision`-making effectiveness, as transparency can be a double-edged weapon. Although it strengthens democracy and allows citizens and stakeholders to participate in the decision-making process, it may sometimes be hampered by increased complexity and delays. On the one hand, opponents of transparency consider that they may lose effectiveness to decision-making processes, as they can cause delays in decision-making due to multiple public debates and intervention by external actors. On the other hand, proponents of transparency see it as enhancing legitimacy and accountability and ensuring that decisions are made in the public\'s interest. Thus, there seems to be a need for an ideal balance between transparency and decision-making effectiveness, as transparency must be made available to citizens and stakeholders without unduly complicating or delaying decision-making processes. The solution may be to develop effective mechanisms to manage potential complexities and ensure smooth decision-making processes, while maintaining a high level of transparency and public participation. In the area of decision-making in particular, transparency may reduce the chances of reaching satisfactory agreements for all. There are several reasons for this: First, transparency may reduce the efficiency of policy outcomes. When the public is aware of the details of the decision, decision makers may be pressured to maintain certain positions or claim additional benefits. This can complicate decision-making, increase its duration, and reduce its flexibility. This may lead to less quality, less comprehensive or less stable agreements. Second, transparency may reduce decision makers\' ability to reach agreement in the first place. When policy options are disclosed, the number of acceptable options for decision makers may decrease. This is because the public may reject, criticize, or oppose certain options. Consequently, it may become difficult for decision makers to move away from their initial positions or prejudice certain interests. This may reduce bargaining space and increase the risk of stalemate or failure. Third, transparency may increase the use of public commitment strategies. These are strategies in which decision makers publicly and openly state their negotiating positions, with a view to strengthening their position or undermining others\' position. This increases transaction costs resulting from changing, modifying, or reversing these positions. This reduces decision makers\' incentives for cooperation, consensus, or central solutions. This increases the likelihood of conflict, division, or breakdown. Based on these reasons, it can be said that transparency is not always useful. Sometimes they can be an obstacle or a danger to achieving the desired goals. There must therefore be a balance between transparency and confidentiality, and the appropriate level of transparency must be chosen for each case, depending on the circumstances (Hagemann, Franchino 2016, p.3). The European Union\'s decision-making studies indicate that there are several factors affecting the efficiency of these processes, including the distribution of preferences and voting rules. The majority vote is known to tend to take decisions faster than the unanimous rules (Golub, 2007). Some studies have found that the European Parliament\'s involvement slows decision-making, even in cases where it has only an advisory role. While some find that the enlargement of the European Union accelerates the decision-making process, others see it as slowing down, and there are those who find little impact. Thus, it appears that multiple factors play a role in the efficiency of decision-making in the European Union, and understanding these factors can help improve decision-making processes and enhance administrative and political effectiveness within the European Union. In addition to known factors affecting t ...
#   'score': 0.7530173063278198}]

# %%
for c in top_chunks: print(c["score"], c["text"])
# Out:
# 0.7530173063278198 Introduction: There is a delicate balance between transparency and `decision`-making effectiveness, as transparency can be a double-edged weapon. Although it strengthens democracy and allows citizens and stakeholders to participate in the decision-making process, it may sometimes be hampered by increased complexity and delays. On the one hand, opponents of transparency consider that they may lose effectiveness to decision-making processes, as they can cause delays in decision-making due to multiple public debates and intervention by external actors. On the other hand, proponents of transparency see it as enhancing legitimacy and accountability and ensuring that decisions are made in the public's interest. Thus, there seems to be a need for an ideal balance between transparency and decision-making effectiveness, as transparency must be made available to citizens and stakeholders without unduly complicating or delaying decision-making processes. The solution may be to develop effective mechanisms to manage potential complexities and ensure smooth decision-making processes, while maintaining a high level of transparency and public participation. In the area of decision-making in particular, transparency may reduce the chances of reaching satisfactory agreements for all. There are several reasons for this: First, transparency may reduce the efficiency of policy outcomes. When the public is aware of the details of the decision, decision makers may be pressured to maintain certain positions or claim additional benefits. This can complicate decision-making, increase its duration, and reduce its flexibility. This may lead to less quality, less comprehensive or less stable agreements. Second, transparency may reduce decision makers' ability to reach agreement in the first place. When policy options are disclosed, the number of acceptable options for decision makers may decrease. This is because the public may reject, criticize, or oppose certain options. Consequently, it may become difficult for decision makers to move away from their initial positions or prejudice certain interests. This may reduce bargaining space and increase the risk of stalemate or failure. Third, transparency may increase the use of public commitment strategies. These are strategies in which decision makers publicly and openly state their negotiating positions, with a view to strengthening their position or undermining others' position. This increases transaction costs resulting from changing, modifying, or reversing these positions. This reduces decision makers' incentives for cooperation, consensus, or central solutions. This increases the likelihood of conflict, division, or breakdown. Based on these reasons, it can be said that transparency is not always useful. Sometimes they can be an obstacle or a danger to achieving the desired goals. There must therefore be a balance between transparency and confidentiality, and the appropriate level of transparency must be chosen for each case, depending on the circumstances (Hagemann, Franchino 2016, p.3). The European Union's decision-making studies indicate that there are several factors affecting the efficiency of these processes, including the distribution of preferences and voting rules. The majority vote is known to tend to take decisions faster than the unanimous rules (Golub, 2007). Some studies have found that the European Parliament's involvement slows decision-making, even in cases where it has only an advisory role. While some find that the enlargement of the European Union accelerates the decision-making process, others see it as slowing down, and there are those who find little impact. Thus, it appears that multiple factors play a role in the efficiency of decision-making in the European Union, and understanding these factors can help improve decision-making processes and enhance administrative and political effectiveness within the European Union. In addition to known factors affecting ...

# %% [markdown]
# **Collect all sentences (no duplicates)**

# %%
all_sentences = []
# collect from chunks
for ch in top_chunks:
    if "sentences" in ch:
        all_sentences.extend(ch["sentences"])

# collect from paragraphs
for para in top_paragraphs:
    if "sentences" in para:
        all_sentences.extend(para["sentences"])

# deduplicate (preserve order)
seen = set()
unique_sentences = []
for s in all_sentences:
    s_clean = s.strip()
    if s_clean not in seen:
        seen.add(s_clean)
        unique_sentences.append(s_clean)

print("Collected", len(unique_sentences), "unique sentences")
# Out:
# Collected 52 unique sentences

# %%
unique_sentences[:3]
# Out:
# ['Introduction: There is a delicate balance between transparency and decision-making effectiveness, as transparency can be a double-edged weapon.',
#  'Although it strengthens democracy and allows citizens and stakeholders to participate in the decision-making process, it may sometimes be hampered by increased complexity and delays.',
#  'On the one hand, opponents of transparency consider that they may lose effectiveness to decision-making processes, as they can cause delays in decision-making due to multiple public debates and intervention by external actors.']

# %% [markdown]
# **Re-rank the unique sentences with a cross-encoder**

# %%
from sentence_transformers import CrossEncoder

# Load a cross-encoder model (choose any you like)
cross_encoder = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2')

# Your user query:
query = "How does transparency impact the effectiveness of decision-making?"

# Prepare (query, sentence) pairs for scoring
pairs = [(query, sent) for sent in unique_sentences]

# Get scores
scores = cross_encoder.predict(pairs)

# Combine & sort by score
ranked = sorted(
    zip(unique_sentences, scores),
    key=lambda x: x[1],
    reverse=True
)

# Top N (e.g. 5 most relevant sentences)
top_n = ranked[:5]

for sent, score in top_n:
    print(f"{score:.3f} - {sent}")
# Out:
# 8.255 - In fact, some research suggests that transparency may reduce the efficiency of decision-making, as it can complicate and slow processes as a result of increased public debate and debate.
# 8.114 - On the one hand, opponents of transparency consider that they may lose effectiveness to decision-making processes, as they can cause delays in decision-making due to multiple public debates and intervention by external actors.
# 8.032 - While some studies have concluded that transparency may reduce the efficiency of decision-making, others see it as contributing to its improvement.
# 7.786 - There seems to be a strong belief among decision makers that transparency negatively affects decision-making efficiency.
# 7.740 - Thus, there seems to be a need for an ideal balance between transparency and decision-making effectiveness, as transparency must be made available to citizens and stakeholders without unduly complicating or delaying decision-making processes.

# %%
top_n
# Out:
# [('In fact, some research suggests that transparency may reduce the efficiency of decision-making, as it can complicate and slow processes as a result of increased public debate and debate.',
#   np.float32(8.254657)),
#  ('On the one hand, opponents of transparency consider that they may lose effectiveness to decision-making processes, as they can cause delays in decision-making due to multiple public debates and intervention by external actors.',
#   np.float32(8.113607)),
#  ('While some studies have concluded that transparency may reduce the efficiency of decision-making, others see it as contributing to its improvement.',
#   np.float32(8.032385)),
#  ('There seems to be a strong belief among decision makers that transparency negatively affects decision-making efficiency.',
#   np.float32(7.78636)),
#  ('Thus, there seems to be a need for an ideal balance between transparency and decision-making effectiveness, as transparency must be made available to citizens and stakeholders without unduly complicating or delaying decision-making processes.',
#   np.float32(7.7396917))]

# %% [markdown]
# **Send Top Sentences to Gemini**

# %%
# pip install google-generativeai
from google import genai

# 1. Configure Gemini with your API key (export GEMINI_API_KEY first)
client = genai.Client(api_key="AIzaSyBCEudgyUMmAVoTlx9fEXbaynRhVBoPPvg".strip())

sentences = [s for s, _ in top_n]

# 3. Build the prompt
prompt = (
    "Act as a professional AI assistant. "
    "You are given the most relevant sentences from a document. "
    "Write a clear, cohesive, and human-readable answer to the user query "
    "based on these sentences.\n\n"
    "Relevant sentences:\n"
    + "\n".join(f"- {s}" for s in sentences) +
    "\n\nAnswer:"
)

# 4. Call Gemini (use gemini-1.5-flash or gemini-2.0-pro if available)
response = client.models.generate_content( model="gemini-2.5-flash", contents=prompt)

# 5. Output the generated text
print(response.text)
# Out:
# The impact of transparency on decision-making efficiency is a subject of debate. Some research and a strong belief among decision-makers suggest that transparency can negatively affect efficiency by complicating and slowing processes, leading to delays due to increased public debate and intervention from external actors. However, other studies propose that transparency can contribute to the improvement of decision-making. Ultimately, there is a recognized need to find an ideal balance, making transparency available to citizens and stakeholders without unduly complicating or delaying decision-making processes.
